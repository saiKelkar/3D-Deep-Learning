# %%
import numpy as np
import pandas as pd
import open3d as o3d
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
data_folder = "DATA/"
results_folder = "DATA/Results/"

pc_dataset = "30HZ1_18_sampled.xyz"
mesh_dataset = "NL.IMBAG.Pand.0637100000139735.obj"

# %%
pcd_df = pd.read_csv(data_folder + pc_dataset, delimiter = ";")
print(pcd_df.columns)
# Out:
# Index(['X', 'Y', 'Z', 'R', 'G', 'B', 'Classification'], dtype='str')

# %%
print(pcd_df.shape)
print(pcd_df.describe())
# Out:
# (7103848, 7)
#                   X             Y             Z             R             G  \
# count  7.103848e+06  7.103848e+06  7.103848e+06  7.103848e+06  7.103848e+06
# mean   9.251568e+04  4.518944e+05  2.546048e+00  1.007054e+02  1.032669e+02
# std    3.048018e+02  3.601502e+02  8.086532e+00  3.556971e+01  3.128933e+01
# min    9.198000e+04  4.512300e+05 -6.470000e+00  2.700000e+01  3.000000e+01
# 25%    9.224665e+04  4.516035e+05 -3.841000e+00  7.400000e+01  7.900000e+01
# 50%    9.254172e+04  4.518916e+05 -8.750000e-01  9.500000e+01  1.010000e+02
# 75%    9.278134e+04  4.522051e+05  6.745000e+00  1.220000e+02  1.220000e+02
# max    9.302000e+04  4.525200e+05  6.803800e+01  2.550000e+02  2.550000e+02
#
#                   B  Classification
# count  7.103848e+06    7.103848e+06
# mean   9.316822e+01    2.234453e+00
# std    2.958742e+01    2.907565e+00
# min    0.000000e+00    1.000000e+00
# 25%    7.200000e+01    1.000000e+00
# 50%    8.700000e+01    2.000000e+00
# 75%    1.090000e+02    2.000000e+00
# max    2.550000e+02    2.600000e+01

# %%
pcd_subsampled = pcd_df.iloc[::2, :]
print(pcd_subsampled.shape)
# Out:
# (3551924, 7)

# %%
pcd_o3d = o3d.geometry.PointCloud()
pcd_o3d.points = o3d.utility.Vector3dVector(np.array(pcd_subsampled[['X', 'Y', 'Z']]))
pcd_o3d.colors = o3d.utility.Vector3dVector(np.array(pcd_subsampled[['R', 'G', 'B']])/255)

# %%
mesh = o3d.io.read_triangle_mesh(data_folder+mesh_dataset)
mesh.paint_uniform_color([0.1, 0.4, 0.8])
# Out:
# TriangleMesh with 512 points and 488 triangles.

# %%
o3d.visualization.draw_geometries([pcd_o3d])
o3d.visualization.draw_geometries([mesh])
# Out:
# [Open3D INFO] Window window_4 created.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 o3d.visualization.draw(pcd_o3d)
#       2 o3d.visualization.draw_geometries([mesh])
#
# File ~/Documents/GitHub/3D_Deep_Learning/05_Developing_Multimodal_3D_Viewer_with_Python/.venv/lib/python3.12/site-packages/open3d/visualization/draw.py:230, in draw(geometry, title, width, height, actions, lookat, eye, up, field_of_view, intrinsic_matrix, extrinsic_matrix, bg_color, bg_image, ibl, ibl_intensity, show_skybox, show_ui, raw_mode, point_size, line_width, animation_time_step, animation_duration, rpc_interface, on_init, on_animation_frame, on_animation_tick, non_blocking_and_return_uid)
#     228     return w.uid
#     229 else:
# --> 230     gui.Application.instance.run()
#
# KeyboardInterrupt:
